# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
data = datasets.load_breast_cancer()

# %%
df = pd.DataFrame(data.data[100:110])
df_target = pd.DataFrame(data.target[100:110])
df
# Out:
#        0      1       2       3        4        5        6        7       8   \
# 0  13.610  24.98   88.05   582.7  0.09488  0.08511  0.08625  0.04489  0.1609
# 1   6.981  13.43   43.79   143.5  0.11700  0.07568  0.00000  0.00000  0.1930
# 2  12.180  20.52   77.22   458.7  0.08013  0.04038  0.02383  0.01770  0.1739
# 3   9.876  19.40   63.95   298.3  0.10050  0.09697  0.06154  0.03029  0.1945
# 4  10.490  19.29   67.41   336.1  0.09989  0.08578  0.02995  0.01201  0.2217
# 5  13.110  15.56   87.21   530.2  0.13980  0.17650  0.20710  0.09601  0.1925
# 6  11.640  18.33   75.17   412.5  0.11420  0.10170  0.07070  0.03485  0.1801
# 7  12.360  18.54   79.01   466.7  0.08477  0.06815  0.02643  0.01921  0.1602
# 8  22.270  19.67  152.80  1509.0  0.13260  0.27680  0.42640  0.18230  0.2556
# 9  11.340  21.26   72.48   396.5  0.08759  0.06575  0.05133  0.01899  0.1487
#
#         9   ...     20     21      22      23      24       25       26  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, df_target, test_size=0.2)
X_test
# Out:
#       0      1       2       3        4        5        6       7       8   \
# 8  22.27  19.67  152.80  1509.0  0.13260  0.27680  0.42640  0.1823  0.2556
# 2  12.18  20.52   77.22   458.7  0.08013  0.04038  0.02383  0.0177  0.1739
#
#         9   ...     20     21      22      23      24       25      26  \
# 8  0.07039  ...  28.40  28.01  206.80  2360.0  0.1701  0.69970  0.9608
# 2  0.05677  ...  13.34  32.84   84.58   547.8  0.1123  0.08862  0.1145
#
#         27      28       29
# 8  0.29100  0.4055  0.09789
# 2  0.07431  0.2694  0.06878
#
# [2 rows x 30 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
a = np.array_split(list(range(data.data.shape[0])), 5)
cv_list = [list(i) for i in a]

# %%
df = pd.DataFrame(data.data)
df_target = pd.DataFrame(data.target)

# %%
for i, item in enumerate(cv_list):
    X_test = np.array(df[df.index.isin(cv_list[i])])
    y_test = np.array(df_target[df_target.index.isin(cv_list[i])])

    X_train = np.array(df[df.index.isin(cv_list[i])==False])
    y_train = np.array(df_target[df_target.index.isin(cv_list[i])==False])
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    y_test.flatten()
    y_test = y_test.flatten()

    counter = 0
    for i in range(len(y_pred)):
        if y_test[i] == y_pred[i]:
            counter = counter + 1
    print('Accuracy: ', round(counter/len(y_pred),3))
# Out:
# Accuracy:  0.86
# Accuracy:  0.921
# Accuracy:  0.947
# Accuracy:  0.921
# Accuracy:  0.85
